# %%
import trimesh

# %%
with open("./data/Ifc4_SampleHouse.obj", 'r') as fp:
    mesh = trimesh.exchange.obj.load_obj(fp)  # keep original face/material ordering
mesh['geometry']['./data/Ifc4_SampleHouse.obj']['visual']
# Each face has a material index (int referring to mesh.visual.materials)
# face_material_indices = mesh.visual.face_materials

# # Material objects (each has .name from MTL's "newmtl")
# materials = mesh.visual.materials

# for face_index, mat_index in enumerate(face_material_indices):
#     material_name = materials[mat_index].name
#     print(f"Face {face_index}: material = {material_name}")
